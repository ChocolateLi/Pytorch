# %%
# !pip install flops-counter.pytorch
# Out:
# ERROR: Could not find a version that satisfies the requirement flops-counter.pytorch (from versions: none)
# ERROR: No matching distribution found for flops-counter.pytorch
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/home/anaconda/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install thop
# Out:
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting torch
#   Downloading torch-2.0.1-cp38-cp38-manylinux1_x86_64.whl (619.9 MB)
#      |█                               | 19.4 MB 6.0 kB/s eta 1 day, 3:56:24ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/urllib3/response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/cachecontrol/filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "/home/anaconda/anaconda3/lib/python3.8/http/client.py", line 458, in read
#     n = self.readinto(b)
#   File "/home/anaconda/anaconda3/lib/python3.8/http/client.py", line 502, in readinto
#     n = self.fp.readinto(b)
#   File "/home/anaconda/anaconda3/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/home/anaconda/anaconda3/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/anaconda/anaconda3/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 173, in _main
#     status = self.run(options, args)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 203, in wrapper
#     return func(self, options, args)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/commands/install.py", line 315, in run
#     requirement_set = resolver.resolve(
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 94, in resolve
#     result = self._result = resolver.resolve(
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 472, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 366, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 212, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 203, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/resolvelib/structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 140, in __bool__
#     return any(self)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 128, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 32, in _iter_built
#     candidate = func()
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 204, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 295, in __init__
#     super().__init__(
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 227, in _prepare
#     dist = self._prepare_distribution()
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 305, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 508, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 550, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 239, in unpack_url
#     file = get_http_url(
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/operations/prepare.py", line 102, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/network/download.py", line 145, in __call__
#     for chunk in chunks:
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/cli/progress_bars.py", line 144, in iter
#     for x in it:
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_internal/network/utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/urllib3/response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/urllib3/response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "/home/anaconda/anaconda3/lib/python3.8/contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/home/anaconda/anaconda3/lib/python3.8/site-packages/pip/_vendor/urllib3/response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/home/anaconda/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import torch
from transformers import BertModel
from thop import profile
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2950648/3943715828.py in <module>
#       1 import torch
# ----> 2 from transformers import BertModel
#       3 from thop import profile
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    2044         elif name in self._class_to_module.keys():
#    2045             module = self._get_module(self._class_to_module[name])
# -> 2046             value = getattr(module, name)
#    2047         else:
#    2048             raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    2043             value = self._get_module(name)
#    2044         elif name in self._class_to_module.keys():
# -> 2045             module = self._get_module(self._class_to_module[name])
#    2046             value = getattr(module, name)
#    2047         else:
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in _get_module(self, module_name)
#    2052
#    2053     def _get_module(self, module_name: str):
# -> 2054         return importlib.import_module("." + module_name, self.__name__)
#    2055
#    2056     def __reduce__(self):
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py in <module>
#      55 )
#      56 from ...utils import logging
# ---> 57 from .configuration_bert import BertConfig
#      58
#      59
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/models/bert/configuration_bert.py in <module>
#      19
#      20 from ...configuration_utils import PretrainedConfig
# ---> 21 from ...onnx import OnnxConfig
#      22 from ...utils import logging
#      23
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/onnx/__init__.py in <module>
#      15
#      16 from .config import EXTERNAL_DATA_FORMAT_SIZE_LIMIT, OnnxConfig, OnnxConfigWithPast, PatchingSpec
# ---> 17 from .convert import export, validate_model_outputs
#      18 from .utils import ParameterFormat, compute_serialized_parameters_size
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/onnx/convert.py in <module>
#      21 from packaging.version import Version, parse
#      22
# ---> 23 from .. import PreTrainedModel, PreTrainedTokenizer, TensorType, TFPreTrainedModel, is_torch_available
#      24 from ..file_utils import is_torch_onnx_dict_inputs_support_available
#      25 from ..utils import logging
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    2043             value = self._get_module(name)
#    2044         elif name in self._class_to_module.keys():
# -> 2045             module = self._get_module(self._class_to_module[name])
#    2046             value = getattr(module, name)
#    2047         else:
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in _get_module(self, module_name)
#    2052
#    2053     def _get_module(self, module_name: str):
# -> 2054         return importlib.import_module("." + module_name, self.__name__)
#    2055
#    2056     def __reduce__(self):
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/modeling_tf_utils.py in <module>
#      25 import h5py
#      26 import numpy as np
# ---> 27 import tensorflow as tf
#      28 from tensorflow.python.keras import backend as K
#      29 from tensorflow.python.keras.engine import data_adapter
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>
#      39 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      40
# ---> 41 from tensorflow.python.eager import context
#      42
#      43 # pylint: enable=wildcard-import
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/python/eager/context.py in <module>
#      30 import six
#      31
# ---> 32 from tensorflow.core.framework import function_pb2
#      33 from tensorflow.core.protobuf import config_pb2
#      34 from tensorflow.core.protobuf import rewriter_config_pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/function_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import attr_value_pb2 as tensorflow_dot_core_dot_framework_dot_attr__value__pb2
#      17 from tensorflow.core.framework import node_def_pb2 as tensorflow_dot_core_dot_framework_dot_node__def__pb2
#      18 from tensorflow.core.framework import op_def_pb2 as tensorflow_dot_core_dot_framework_dot_op__def__pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/attr_value_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/tensor_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import resource_handle_pb2 as tensorflow_dot_core_dot_framework_dot_resource__handle__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/resource_handle_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#      18
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/tensor_shape_pb2.py in <module>
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
# ---> 42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='name', full_name='tensorflow.TensorShapeProto.Dim.name', index=1,
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/google/protobuf/descriptor.py in __new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     559                 has_default_value=True, containing_oneof=None, json_name=None,
#     560                 file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 561       _message.Message._CheckCalledFromGeneratedFile()
#     562       if is_extension:
#     563         return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
import torch
from transformers import BertModel
from thop import profile


model = BertModel.from_pretrained("bert-base-chinese") 
input_shape = (1, 512) # some example input shape
input_tensor = torch.rand(*input_shape)

flops, params = profile(model, inputs=(input_tensor,))
print(f"Model flops: {flops}")
print(f"Model parameters: {params}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2950648/4269714359.py in <module>
#       1 import torch
# ----> 2 from transformers import BertModel
#       3 from thop import profile
#       4
#       5
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    2044         elif name in self._class_to_module.keys():
#    2045             module = self._get_module(self._class_to_module[name])
# -> 2046             value = getattr(module, name)
#    2047         else:
#    2048             raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    2043             value = self._get_module(name)
#    2044         elif name in self._class_to_module.keys():
# -> 2045             module = self._get_module(self._class_to_module[name])
#    2046             value = getattr(module, name)
#    2047         else:
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in _get_module(self, module_name)
#    2052
#    2053     def _get_module(self, module_name: str):
# -> 2054         return importlib.import_module("." + module_name, self.__name__)
#    2055
#    2056     def __reduce__(self):
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py in <module>
#      55 )
#      56 from ...utils import logging
# ---> 57 from .configuration_bert import BertConfig
#      58
#      59
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/models/bert/configuration_bert.py in <module>
#      19
#      20 from ...configuration_utils import PretrainedConfig
# ---> 21 from ...onnx import OnnxConfig
#      22 from ...utils import logging
#      23
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/onnx/__init__.py in <module>
#      15
#      16 from .config import EXTERNAL_DATA_FORMAT_SIZE_LIMIT, OnnxConfig, OnnxConfigWithPast, PatchingSpec
# ---> 17 from .convert import export, validate_model_outputs
#      18 from .utils import ParameterFormat, compute_serialized_parameters_size
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/onnx/convert.py in <module>
#      21 from packaging.version import Version, parse
#      22
# ---> 23 from .. import PreTrainedModel, PreTrainedTokenizer, TensorType, TFPreTrainedModel, is_torch_available
#      24 from ..file_utils import is_torch_onnx_dict_inputs_support_available
#      25 from ..utils import logging
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    2043             value = self._get_module(name)
#    2044         elif name in self._class_to_module.keys():
# -> 2045             module = self._get_module(self._class_to_module[name])
#    2046             value = getattr(module, name)
#    2047         else:
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in _get_module(self, module_name)
#    2052
#    2053     def _get_module(self, module_name: str):
# -> 2054         return importlib.import_module("." + module_name, self.__name__)
#    2055
#    2056     def __reduce__(self):
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/modeling_tf_utils.py in <module>
#      25 import h5py
#      26 import numpy as np
# ---> 27 import tensorflow as tf
#      28 from tensorflow.python.keras import backend as K
#      29 from tensorflow.python.keras.engine import data_adapter
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>
#      39 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      40
# ---> 41 from tensorflow.python.eager import context
#      42
#      43 # pylint: enable=wildcard-import
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/python/eager/context.py in <module>
#      30 import six
#      31
# ---> 32 from tensorflow.core.framework import function_pb2
#      33 from tensorflow.core.protobuf import config_pb2
#      34 from tensorflow.core.protobuf import rewriter_config_pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/function_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import attr_value_pb2 as tensorflow_dot_core_dot_framework_dot_attr__value__pb2
#      17 from tensorflow.core.framework import node_def_pb2 as tensorflow_dot_core_dot_framework_dot_node__def__pb2
#      18 from tensorflow.core.framework import op_def_pb2 as tensorflow_dot_core_dot_framework_dot_op__def__pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/attr_value_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/tensor_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import resource_handle_pb2 as tensorflow_dot_core_dot_framework_dot_resource__handle__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/resource_handle_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#      18
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/tensor_shape_pb2.py in <module>
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
# ---> 42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='name', full_name='tensorflow.TensorShapeProto.Dim.name', index=1,
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/google/protobuf/descriptor.py in __new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     559                 has_default_value=True, containing_oneof=None, json_name=None,
#     560                 file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 561       _message.Message._CheckCalledFromGeneratedFile()
#     562       if is_extension:
#     563         return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
import torch
from transformers import AutoModel
from thop import profile

check_point = "schen/longformer-chinese-base-4096"
model = AutoModel.from_pretrained(check_point) 
input_shape = (1, 512) # some example input shape
input_tensor = torch.rand(*input_shape)

flops, params = profile(model, inputs=(input_tensor,))
print(f"Model flops: {flops}")
print(f"Model parameters: {params}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2950648/87578543.py in <module>
#       4
#       5 check_point = "schen/longformer-chinese-base-4096"
# ----> 6 model = AutoModel.from_pretrained(check_point)
#       7 input_shape = (1, 512) # some example input shape
#       8 input_tensor = torch.rand(*input_shape)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     395         if not isinstance(config, PretrainedConfig):
#     396             config, kwargs = AutoConfig.from_pretrained(
# --> 397                 pretrained_model_name_or_path, return_unused_kwargs=True, **kwargs
#     398             )
#     399         if hasattr(config, "auto_map") and cls.__name__ in config.auto_map:
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     527         config_dict, _ = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     528         if "model_type" in config_dict:
# --> 529             config_class = CONFIG_MAPPING[config_dict["model_type"]]
#     530             return config_class.from_dict(config_dict, **kwargs)
#     531         else:
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/models/auto/configuration_auto.py in __getitem__(self, key)
#     281         if module_name not in self._modules:
#     282             self._modules[module_name] = importlib.import_module(f".{module_name}", "transformers.models")
# --> 283         return getattr(self._modules[module_name], value)
#     284
#     285     def keys(self):
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    2043             value = self._get_module(name)
#    2044         elif name in self._class_to_module.keys():
# -> 2045             module = self._get_module(self._class_to_module[name])
#    2046             value = getattr(module, name)
#    2047         else:
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in _get_module(self, module_name)
#    2052
#    2053     def _get_module(self, module_name: str):
# -> 2054         return importlib.import_module("." + module_name, self.__name__)
#    2055
#    2056     def __reduce__(self):
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/models/bert/configuration_bert.py in <module>
#      19
#      20 from ...configuration_utils import PretrainedConfig
# ---> 21 from ...onnx import OnnxConfig
#      22 from ...utils import logging
#      23
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/onnx/__init__.py in <module>
#      15
#      16 from .config import EXTERNAL_DATA_FORMAT_SIZE_LIMIT, OnnxConfig, OnnxConfigWithPast, PatchingSpec
# ---> 17 from .convert import export, validate_model_outputs
#      18 from .utils import ParameterFormat, compute_serialized_parameters_size
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/onnx/convert.py in <module>
#      21 from packaging.version import Version, parse
#      22
# ---> 23 from .. import PreTrainedModel, PreTrainedTokenizer, TensorType, TFPreTrainedModel, is_torch_available
#      24 from ..file_utils import is_torch_onnx_dict_inputs_support_available
#      25 from ..utils import logging
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    2043             value = self._get_module(name)
#    2044         elif name in self._class_to_module.keys():
# -> 2045             module = self._get_module(self._class_to_module[name])
#    2046             value = getattr(module, name)
#    2047         else:
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/file_utils.py in _get_module(self, module_name)
#    2052
#    2053     def _get_module(self, module_name: str):
# -> 2054         return importlib.import_module("." + module_name, self.__name__)
#    2055
#    2056     def __reduce__(self):
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/transformers/modeling_tf_utils.py in <module>
#      25 import h5py
#      26 import numpy as np
# ---> 27 import tensorflow as tf
#      28 from tensorflow.python.keras import backend as K
#      29 from tensorflow.python.keras.engine import data_adapter
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>
#      39 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      40
# ---> 41 from tensorflow.python.eager import context
#      42
#      43 # pylint: enable=wildcard-import
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/python/eager/context.py in <module>
#      30 import six
#      31
# ---> 32 from tensorflow.core.framework import function_pb2
#      33 from tensorflow.core.protobuf import config_pb2
#      34 from tensorflow.core.protobuf import rewriter_config_pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/function_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import attr_value_pb2 as tensorflow_dot_core_dot_framework_dot_attr__value__pb2
#      17 from tensorflow.core.framework import node_def_pb2 as tensorflow_dot_core_dot_framework_dot_node__def__pb2
#      18 from tensorflow.core.framework import op_def_pb2 as tensorflow_dot_core_dot_framework_dot_op__def__pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/attr_value_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/tensor_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import resource_handle_pb2 as tensorflow_dot_core_dot_framework_dot_resource__handle__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/resource_handle_pb2.py in <module>
#      14
#      15
# ---> 16 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#      18
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/tensorflow/core/framework/tensor_shape_pb2.py in <module>
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
# ---> 42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='name', full_name='tensorflow.TensorShapeProto.Dim.name', index=1,
#
# /home/anaconda/anaconda3/envs/pytorch/lib/python3.7/site-packages/google/protobuf/descriptor.py in __new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     559                 has_default_value=True, containing_oneof=None, json_name=None,
#     560                 file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 561       _message.Message._CheckCalledFromGeneratedFile()
#     562       if is_extension:
#     563         return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
